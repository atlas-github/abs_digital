# %% [markdown]
# <a href="https://colab.research.google.com/github/atlas-github/abs_digital/blob/master/Extracting_text_from_images_PDFs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Extract information from a PDF document using [Tabula](https://pypi.org/project/tabula-py/)

# %% [markdown]
# Tabula isn't usually installed in most IDEs, so install the library using the code below.

# %%
# !pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading https://files.pythonhosted.org/packages/cf/29/d6cb0d77ef46d84d35cffa09cf42c73b373aea664d28604eab6818f8a47c/tabula_py-2.2.0-py3-none-any.whl (11.7MB)
#      |████████████████████████████████| 11.7MB 9.3MB/s
# Collecting distro
#   Downloading https://files.pythonhosted.org/packages/25/b7/b3c4270a11414cb22c6352ebc7a83aaa3712043be29daa05018fd5a5c956/distro-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tabula-py) (1.18.5)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.6/dist-packages (from tabula-py) (1.1.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->tabula-py) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.5.0 tabula-py-2.2.0

# %% [markdown]
# I'll be demonstrating how to extract information from page 45 of a survey conducted by a news agency in the US, which can be found [here](https://www.usnews.com/static/documents/health/best-hospitals/BH_Methodology_2018-19.pdf).

# %%
import tabula

# Read pdf into list of DataFrame
sample_list = tabula.read_pdf("BH_Methodology_2018-19.pdf", pages='45')

sample_list
# Out:
# Got stderr: Dec 09, 2020 3:53:42 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Dec 09, 2020 3:53:42 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Dec 09, 2020 3:53:42 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Dec 09, 2020 3:53:42 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Dec 09, 2020 3:53:44 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# [                       Unnamed: 0 Unnamed: 1 Midwest  ...  South   West  Total
#  0                             NaN  Specialty     (%)  ...    (%)    (%)    (%)
#  1                          Cancer        NaN    30.2  ...   40.3   29.7   35.4
#  2        Diabetes & Endocrinology        NaN    34.5  ...   28.3   13.9   24.4
#  3              Ear, Nose & Throat        NaN    16.7  ...   29.0   39.0   29.9
#  4   Gastroenterology & GI Surgery        NaN    24.3  ...   24.6   12.8   24.7
#  5                      Geriatrics        NaN    15.2  ...   13.3   13.8   14.5
#  6                      Gynecology        NaN    25.8  ...   28.3   13.5   23.0
#  7           Heart & Heart Surgery        NaN    36.1  ...   18.8   32.4   30.6
#  8                      Nephrology        NaN    25.7  ...   17.9   17.1   19.9
#  9        Neurology & Neurosurgery        NaN    20.6  ...   17.5   25.7   22.2
#  10                  Ophthalmology        NaN    28.1  ...   21.7   24.4   24.0
#  11                    Orthopedics        NaN    25.7  ...   19.7   21.3   22.2
#  12                     Psychiatry        NaN    29.2  ...   17.1   16.7   18.6
#  13                    Pulmonology        NaN    13.8  ...   32.7   31.6   25.2
#  14                 Rehabilitation        NaN    21.2  ...   32.7   12.5   24.2
#  15                   Rheumatology        NaN    13.3  ...   26.9    7.7   17.7
#  16                        Urology        NaN    23.5  ...   25.4   10.5   24.1
#  17          Overall Response Rate        NaN   24.2%  ...  24.8%  20.3%  24.0%
#
#  [18 rows x 7 columns]]

# %% [markdown]
# Now to convert the result into a table.

# %%
import numpy as np 

df = sample_list[0]
df
# Out:
#                        Unnamed: 0 Unnamed: 1 Midwest  ...  South   West  Total
# 0                             NaN  Specialty     (%)  ...    (%)    (%)    (%)
# 1                          Cancer        NaN    30.2  ...   40.3   29.7   35.4
# 2        Diabetes & Endocrinology        NaN    34.5  ...   28.3   13.9   24.4
# 3              Ear, Nose & Throat        NaN    16.7  ...   29.0   39.0   29.9
# 4   Gastroenterology & GI Surgery        NaN    24.3  ...   24.6   12.8   24.7
# 5                      Geriatrics        NaN    15.2  ...   13.3   13.8   14.5
# 6                      Gynecology        NaN    25.8  ...   28.3   13.5   23.0
# 7           Heart & Heart Surgery        NaN    36.1  ...   18.8   32.4   30.6
# 8                      Nephrology        NaN    25.7  ...   17.9   17.1   19.9
# 9        Neurology & Neurosurgery        NaN    20.6  ...   17.5   25.7   22.2
# 10                  Ophthalmology        NaN    28.1  ...   21.7   24.4   24.0
# 11                    Orthopedics        NaN    25.7  ...   19.7   21.3   22.2
# 12                     Psychiatry        NaN    29.2  ...   17.1   16.7   18.6
# 13                    Pulmonology        NaN    13.8  ...   32.7   31.6   25.2
# 14                 Rehabilitation        NaN    21.2  ...   32.7   12.5   24.2
# 15                   Rheumatology        NaN    13.3  ...   26.9    7.7   17.7
# 16                        Urology        NaN    23.5  ...   25.4   10.5   24.1
# 17          Overall Response Rate        NaN   24.2%  ...  24.8%  20.3%  24.0%
#
# [18 rows x 7 columns]

# %%
#Replaces all NaNs
df = df.replace(np.nan, '', regex = True)

#Merge first two columns
df["Unnamed: 0"] = df["Unnamed: 0"] + df["Unnamed: 1"]

#Drop second row
df = df.drop([0])

#Drop second column
df = df.drop(["Unnamed: 1"], axis = 1)

#Rename columns
df = df.rename(columns = {"Unnamed: 0": "Specialty", "Midwest": "Midwest (%)", 
                          "Northeast": "Northeast (%)", "South": "South (%)", 
                          "West": "West (%)"})

df
# Out:
#                         Specialty Midwest (%)  ... West (%)  Total
# 1                          Cancer        30.2  ...     29.7   35.4
# 2        Diabetes & Endocrinology        34.5  ...     13.9   24.4
# 3              Ear, Nose & Throat        16.7  ...     39.0   29.9
# 4   Gastroenterology & GI Surgery        24.3  ...     12.8   24.7
# 5                      Geriatrics        15.2  ...     13.8   14.5
# 6                      Gynecology        25.8  ...     13.5   23.0
# 7           Heart & Heart Surgery        36.1  ...     32.4   30.6
# 8                      Nephrology        25.7  ...     17.1   19.9
# 9        Neurology & Neurosurgery        20.6  ...     25.7   22.2
# 10                  Ophthalmology        28.1  ...     24.4   24.0
# 11                    Orthopedics        25.7  ...     21.3   22.2
# 12                     Psychiatry        29.2  ...     16.7   18.6
# 13                    Pulmonology        13.8  ...     31.6   25.2
# 14                 Rehabilitation        21.2  ...     12.5   24.2
# 15                   Rheumatology        13.3  ...      7.7   17.7
# 16                        Urology        23.5  ...     10.5   24.1
# 17          Overall Response Rate       24.2%  ...    20.3%  24.0%
#
# [17 rows x 6 columns]

# %% [markdown]
# And if you would like to export the file.

# %%
result.to_csv("result.csv")
from google.colab import files
files.download("result.csv")

# %% [markdown]
# #Extract information from Google Vision API's [OCR](https://cloud.google.com/vision/docs/ocr) (Optical Character Recognition).

# %% [markdown]
# Start by setting up definitions based on Google Vision API's [OCR](https://cloud.google.com/vision/docs/ocr). The GOOGLE_APPLICATION_CREDENTIALS file can be obtained by creating a service account key using this [method](https://cloud.google.com/docs/authentication/production).

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="OCRproject-135c7e667aa9.json"

def implicit():
    from google.cloud import storage

    # If you don't specify credentials when constructing the client, the
    # client library will look for credentials in the environment.
    storage_client = storage.Client()

    # Make an authenticated API request
    buckets = list(storage_client.list_buckets())
    print(buckets)

def detect_text(path):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    
    #print('Texts:')
    
    return texts

# %% [markdown]
# Install the google-cloud-vision library if it has not been installed in your IDE.

# %%
# !pip install google-cloud-vision

# %% [markdown]
# For this demonstration, I will be extracting the table listing electrical usage from [here](https://www.tnb.com.my/assets/images/bill_with_sstv2.png).

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

tnb_text = detect_text("bill_with_sstv2.png")
tnb_text
# Out:
# [locale: "ms"
# description: "BIL ELEKTRIK ANDA\nTENAGA\nNASIONAL\nNo. Akaun : 220001234512\n: 1002000\n: RM350.00\nTERIMA KASIH\nNo. Kontrak\nKerana\nDeposit\nNo. Invois\nMembayar Dalam\nTempoh 30 Hari\n: 10001234\nAli bin Abu\n3\nTNB Careline\n1-300-88-5454\nE23A - 201 Sek 3\nWangsa Maju\n53300\nWP Kuala Lumpur\nTarikh Bil\nJumlahPerlu Dibayar RM311.90\n03 Okt 2018\nAmaun\nBayar Sebelum\nTunggakan\nCaj Semasa\nPenggenapan\nRM\n0.00\nTerima kasih\nRM 311.88\n0,02\nRM\nJumlah Bil\nRM\n311.90\n01.11.2018\nAmaun\n52685\nTarikh\n5\nBil Terdahulu\nRM\n02.08.2018\nBayaran Akhir\nRM\n526.85\n30.08.2018\nJenis Bacaan\nBacaan Sebenar\nTempoh Bil : 03.09.2018 - 03.10.2018 (31 Hari)\nTarif\nFaktor Prorata\n:A: Kediaman\n1,00000\nBlok Tarif (KWh)\n200\n100\n300\n300\nBlok Prorata (kWh)\n200\n100\n300\n130\nKadar (RM)\n0.218\nAmaun (RM)\n43.60\n33.40\n154.80\n70.98\n8\n0.334\n0.516\n0.546\nJumlah\n730\n302.78\nTidak Kena\nST\nKena\nST\nKeterangan\nJumlah\nKegunaan kWh\nKegunaan\nkWh\n600\n130\n730\nRM\n231.80\n70.98\n302.78\nKegunaan Bulan Semasa\nService Tax (66)\nKWTBB (1.6%)\nRM\n231.80\n70.98\n302.78\n4.26\n4.84\n10\nCaj Semasa\nRM\n311.88\nBacaan Meter\nNo Meter\n\320\232egunaan\nUnit\nDahulu\nSemasa\n311201234\n28470\n29200\n730\nkWh\nSubsidi 1.35 sen/kWh diblayai Kerajaan Persekutuan RM 10.61\nService Tax (ST) 6% bagi penggunaan Domestik melebihi 600 kWh\nBayaran melalui cek sah setelah penjelasan cek oleh bank\n*22000123451200010001234000000000031190\nAli bin Abu\nE2SA - 201 Sek 3\nWangsa Maju\n53300\nWP Kuala Lumpur\nRM\n311.90\nAras 17, Wisma TNB, No. 19. Jalan Timur, 46200 Petaling Jaya, Selangor.\nTENAGA NASIONAL BERHAD (200006), Nombor Datar ST W10-1608-31022372\n"
# bounding_poly {
#   vertices {
#     x: 1
#     y: 14
#   }
#   vertices {
#     x: 325
#     y: 14
#   }
#   vertices {
#     x: 325
#     y: 921
#   }
#   vertices {
#     x: 1
#     y: 921
#   }
# }
# , description: "BIL"
# bounding_poly {
#   vertices {
#     x: 34
#     y: 14
#   }
#   vertices {
#     x: 47
#     y: 14
#   }
#   vertices {
#     x: 47
#     y: 20
#   }
#   vertices {
#     x: 34
#     y: 20
#   }
# }
# , description: "ELEKTRIK"
# bounding_poly {
#   vertices {
#     x: 52
#     y: 14
#   }
#   vertices {
#     x: 97
#     y: 14
#   }
#   vertices {
#     x: 97
#     y: 20
#   }
#   vertices {
#     x: 52
#     y: 20
#   }
# }
# , description: "ANDA"
# bounding_poly {
#   vertices {
#     x: 101
#     y: 14
#   }
#   vertices {
#     x: 125
#     y: 14
#   }
#   vertices {
#     x: 125
#     y: 20
#   }
#   vertices {
#     x: 101
#     y: 20
#   }
# }
# , description: "TENAGA"
# bounding_poly {
#   vertices {
#     x: 291
#     y: 18
#   }
#   vertices {
#     x: 316
#     y: 18
#   }
#   vertices {
#     x: 316
#     y: 23
#   }
#   vertices {
#     x: 291
#     y: 23
#   }
# }
# , description: "NASIONAL"
# bounding_poly {
#   vertices {
#     x: 291
#     y: 23
#   }
#   vertices {
#     x: 325
#     y: 23
#   }
#   vertices {
#     x: 325
#     y: 29
#   }
#   vertices {
#     x: 291
#     y: 29
#   }
# }
# , description: "No."
# bounding_poly {
#   vertices {
#     x: 38
#     y: 40
#   }
#   vertices {
#     x: 53
#     y: 40
#   }
#   vertices {
#     x: 53
#     y: 48
#   }
#   vertices {
#     x: 38
#     y: 48
#   }
# }
# , description: "Akaun"
# bounding_poly {
#   vertices {
#     x: 57
#     y: 40
#   }
#   vertices {
#     x: 87
#     y: 40
#   }
#   vertices {
#     x: 87
#     y: 48
#   }
#   vertices {
#     x: 57
#     y: 48
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 100
#     y: 39
#   }
#   vertices {
#     x: 104
#     y: 39
#   }
#   vertices {
#     x: 104
#     y: 50
#   }
#   vertices {
#     x: 100
#     y: 50
#   }
# }
# , description: "220001234512"
# bounding_poly {
#   vertices {
#     x: 105
#     y: 42
#   }
#   vertices {
#     x: 157
#     y: 42
#   }
#   vertices {
#     x: 157
#     y: 48
#   }
#   vertices {
#     x: 105
#     y: 48
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 99
#     y: 51
#   }
#   vertices {
#     x: 105
#     y: 51
#   }
#   vertices {
#     x: 105
#     y: 61
#   }
#   vertices {
#     x: 99
#     y: 61
#   }
# }
# , description: "1002000"
# bounding_poly {
#   vertices {
#     x: 105
#     y: 53
#   }
#   vertices {
#     x: 135
#     y: 53
#   }
#   vertices {
#     x: 135
#     y: 59
#   }
#   vertices {
#     x: 105
#     y: 59
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 100
#     y: 65
#   }
#   vertices {
#     x: 100
#     y: 65
#   }
#   vertices {
#     x: 100
#     y: 69
#   }
#   vertices {
#     x: 100
#     y: 69
#   }
# }
# , description: "RM350.00"
# bounding_poly {
#   vertices {
#     x: 105
#     y: 63
#   }
#   vertices {
#     x: 140
#     y: 63
#   }
#   vertices {
#     x: 140
#     y: 69
#   }
#   vertices {
#     x: 105
#     y: 69
#   }
# }
# , description: "TERIMA"
# bounding_poly {
#   vertices {
#     x: 249
#     y: 48
#   }
#   vertices {
#     x: 282
#     y: 48
#   }
#   vertices {
#     x: 282
#     y: 54
#   }
#   vertices {
#     x: 249
#     y: 54
#   }
# }
# , description: "KASIH"
# bounding_poly {
#   vertices {
#     x: 285
#     y: 48
#   }
#   vertices {
#     x: 311
#     y: 48
#   }
#   vertices {
#     x: 311
#     y: 54
#   }
#   vertices {
#     x: 285
#     y: 54
#   }
# }
# , description: "No."
# bounding_poly {
#   vertices {
#     x: 38
#     y: 53
#   }
#   vertices {
#     x: 49
#     y: 53
#   }
#   vertices {
#     x: 49
#     y: 59
#   }
#   vertices {
#     x: 38
#     y: 59
#   }
# }
# , description: "Kontrak"
# bounding_poly {
#   vertices {
#     x: 53
#     y: 53
#   }
#   vertices {
#     x: 80
#     y: 53
#   }
#   vertices {
#     x: 80
#     y: 59
#   }
#   vertices {
#     x: 53
#     y: 59
#   }
# }
# , description: "Kerana"
# bounding_poly {
#   vertices {
#     x: 264
#     y: 59
#   }
#   vertices {
#     x: 292
#     y: 59
#   }
#   vertices {
#     x: 292
#     y: 65
#   }
#   vertices {
#     x: 264
#     y: 65
#   }
# }
# , description: "Deposit"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 64
#   }
#   vertices {
#     x: 64
#     y: 64
#   }
#   vertices {
#     x: 64
#     y: 71
#   }
#   vertices {
#     x: 38
#     y: 71
#   }
# }
# , description: "No."
# bounding_poly {
#   vertices {
#     x: 38
#     y: 74
#   }
#   vertices {
#     x: 49
#     y: 74
#   }
#   vertices {
#     x: 49
#     y: 80
#   }
#   vertices {
#     x: 38
#     y: 80
#   }
# }
# , description: "Invois"
# bounding_poly {
#   vertices {
#     x: 53
#     y: 74
#   }
#   vertices {
#     x: 73
#     y: 74
#   }
#   vertices {
#     x: 73
#     y: 80
#   }
#   vertices {
#     x: 53
#     y: 80
#   }
# }
# , description: "Membayar"
# bounding_poly {
#   vertices {
#     x: 243
#     y: 68
#   }
#   vertices {
#     x: 285
#     y: 68
#   }
#   vertices {
#     x: 285
#     y: 78
#   }
#   vertices {
#     x: 243
#     y: 78
#   }
# }
# , description: "Dalam"
# bounding_poly {
#   vertices {
#     x: 287
#     y: 68
#   }
#   vertices {
#     x: 313
#     y: 68
#   }
#   vertices {
#     x: 313
#     y: 78
#   }
#   vertices {
#     x: 287
#     y: 78
#   }
# }
# , description: "Tempoh"
# bounding_poly {
#   vertices {
#     x: 246
#     y: 75
#   }
#   vertices {
#     x: 278
#     y: 75
#   }
#   vertices {
#     x: 278
#     y: 84
#   }
#   vertices {
#     x: 246
#     y: 84
#   }
# }
# , description: "30"
# bounding_poly {
#   vertices {
#     x: 282
#     y: 77
#   }
#   vertices {
#     x: 290
#     y: 77
#   }
#   vertices {
#     x: 290
#     y: 83
#   }
#   vertices {
#     x: 282
#     y: 83
#   }
# }
# , description: "Hari"
# bounding_poly {
#   vertices {
#     x: 295
#     y: 77
#   }
#   vertices {
#     x: 310
#     y: 77
#   }
#   vertices {
#     x: 310
#     y: 83
#   }
#   vertices {
#     x: 295
#     y: 83
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 100
#     y: 73
#   }
#   vertices {
#     x: 106
#     y: 73
#   }
#   vertices {
#     x: 106
#     y: 82
#   }
#   vertices {
#     x: 100
#     y: 82
#   }
# }
# , description: "10001234"
# bounding_poly {
#   vertices {
#     x: 108
#     y: 73
#   }
#   vertices {
#     x: 139
#     y: 73
#   }
#   vertices {
#     x: 139
#     y: 82
#   }
#   vertices {
#     x: 108
#     y: 82
#   }
# }
# , description: "Ali"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 89
#   }
#   vertices {
#     x: 45
#     y: 89
#   }
#   vertices {
#     x: 45
#     y: 93
#   }
#   vertices {
#     x: 38
#     y: 93
#   }
# }
# , description: "bin"
# bounding_poly {
#   vertices {
#     x: 48
#     y: 89
#   }
#   vertices {
#     x: 57
#     y: 89
#   }
#   vertices {
#     x: 57
#     y: 94
#   }
#   vertices {
#     x: 48
#     y: 94
#   }
# }
# , description: "Abu"
# bounding_poly {
#   vertices {
#     x: 60
#     y: 89
#   }
#   vertices {
#     x: 72
#     y: 89
#   }
#   vertices {
#     x: 72
#     y: 94
#   }
#   vertices {
#     x: 60
#     y: 94
#   }
# }
# , description: "3"
# bounding_poly {
#   vertices {
#     x: 1
#     y: 90
#   }
#   vertices {
#     x: 20
#     y: 90
#   }
#   vertices {
#     x: 20
#     y: 108
#   }
#   vertices {
#     x: 1
#     y: 108
#   }
# }
# , description: "TNB"
# bounding_poly {
#   vertices {
#     x: 251
#     y: 93
#   }
#   vertices {
#     x: 270
#     y: 93
#   }
#   vertices {
#     x: 270
#     y: 102
#   }
#   vertices {
#     x: 251
#     y: 102
#   }
# }
# , description: "Careline"
# bounding_poly {
#   vertices {
#     x: 272
#     y: 93
#   }
#   vertices {
#     x: 305
#     y: 93
#   }
#   vertices {
#     x: 305
#     y: 102
#   }
#   vertices {
#     x: 272
#     y: 102
#   }
# }
# , description: "1-300-88-5454"
# bounding_poly {
#   vertices {
#     x: 250
#     y: 102
#   }
#   vertices {
#     x: 306
#     y: 102
#   }
#   vertices {
#     x: 306
#     y: 108
#   }
#   vertices {
#     x: 250
#     y: 108
#   }
# }
# , description: "E23A"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 100
#   }
#   vertices {
#     x: 51
#     y: 100
#   }
#   vertices {
#     x: 51
#     y: 104
#   }
#   vertices {
#     x: 38
#     y: 104
#   }
# }
# , description: "-"
# bounding_poly {
#   vertices {
#     x: 53
#     y: 102
#   }
#   vertices {
#     x: 54
#     y: 102
#   }
#   vertices {
#     x: 54
#     y: 102
#   }
#   vertices {
#     x: 53
#     y: 102
#   }
# }
# , description: "201"
# bounding_poly {
#   vertices {
#     x: 57
#     y: 100
#   }
#   vertices {
#     x: 65
#     y: 100
#   }
#   vertices {
#     x: 65
#     y: 104
#   }
#   vertices {
#     x: 57
#     y: 104
#   }
# }
# , description: "Sek"
# bounding_poly {
#   vertices {
#     x: 68
#     y: 100
#   }
#   vertices {
#     x: 77
#     y: 100
#   }
#   vertices {
#     x: 77
#     y: 104
#   }
#   vertices {
#     x: 68
#     y: 104
#   }
# }
# , description: "3"
# bounding_poly {
#   vertices {
#     x: 80
#     y: 100
#   }
#   vertices {
#     x: 81
#     y: 100
#   }
#   vertices {
#     x: 81
#     y: 104
#   }
#   vertices {
#     x: 80
#     y: 104
#   }
# }
# , description: "Wangsa"
# bounding_poly {
#   vertices {
#     x: 37
#     y: 109
#   }
#   vertices {
#     x: 58
#     y: 109
#   }
#   vertices {
#     x: 58
#     y: 114
#   }
#   vertices {
#     x: 37
#     y: 114
#   }
# }
# , description: "Maju"
# bounding_poly {
#   vertices {
#     x: 61
#     y: 109
#   }
#   vertices {
#     x: 73
#     y: 109
#   }
#   vertices {
#     x: 73
#     y: 114
#   }
#   vertices {
#     x: 61
#     y: 114
#   }
# }
# , description: "53300"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 117
#   }
#   vertices {
#     x: 54
#     y: 117
#   }
#   vertices {
#     x: 54
#     y: 122
#   }
#   vertices {
#     x: 38
#     y: 122
#   }
# }
# , description: "WP"
# bounding_poly {
#   vertices {
#     x: 37
#     y: 126
#   }
#   vertices {
#     x: 46
#     y: 126
#   }
#   vertices {
#     x: 46
#     y: 130
#   }
#   vertices {
#     x: 37
#     y: 130
#   }
# }
# , description: "Kuala"
# bounding_poly {
#   vertices {
#     x: 48
#     y: 126
#   }
#   vertices {
#     x: 62
#     y: 126
#   }
#   vertices {
#     x: 62
#     y: 130
#   }
#   vertices {
#     x: 48
#     y: 130
#   }
# }
# , description: "Lumpur"
# bounding_poly {
#   vertices {
#     x: 65
#     y: 126
#   }
#   vertices {
#     x: 85
#     y: 126
#   }
#   vertices {
#     x: 85
#     y: 131
#   }
#   vertices {
#     x: 65
#     y: 131
#   }
# }
# , description: "Tarikh"
# bounding_poly {
#   vertices {
#     x: 266
#     y: 136
#   }
#   vertices {
#     x: 287
#     y: 136
#   }
#   vertices {
#     x: 287
#     y: 142
#   }
#   vertices {
#     x: 266
#     y: 142
#   }
# }
# , description: "Bil"
# bounding_poly {
#   vertices {
#     x: 290
#     y: 136
#   }
#   vertices {
#     x: 298
#     y: 136
#   }
#   vertices {
#     x: 298
#     y: 142
#   }
#   vertices {
#     x: 290
#     y: 142
#   }
# }
# , description: "JumlahPerlu"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 142
#   }
#   vertices {
#     x: 102
#     y: 142
#   }
#   vertices {
#     x: 102
#     y: 150
#   }
#   vertices {
#     x: 38
#     y: 150
#   }
# }
# , description: "Dibayar"
# bounding_poly {
#   vertices {
#     x: 107
#     y: 142
#   }
#   vertices {
#     x: 146
#     y: 142
#   }
#   vertices {
#     x: 146
#     y: 152
#   }
#   vertices {
#     x: 107
#     y: 152
#   }
# }
# , description: "RM311.90"
# bounding_poly {
#   vertices {
#     x: 151
#     y: 142
#   }
#   vertices {
#     x: 199
#     y: 142
#   }
#   vertices {
#     x: 199
#     y: 150
#   }
#   vertices {
#     x: 151
#     y: 150
#   }
# }
# , description: "03"
# bounding_poly {
#   vertices {
#     x: 258
#     y: 149
#   }
#   vertices {
#     x: 267
#     y: 149
#   }
#   vertices {
#     x: 267
#     y: 154
#   }
#   vertices {
#     x: 258
#     y: 154
#   }
# }
# , description: "Okt"
# bounding_poly {
#   vertices {
#     x: 271
#     y: 149
#   }
#   vertices {
#     x: 284
#     y: 149
#   }
#   vertices {
#     x: 284
#     y: 154
#   }
#   vertices {
#     x: 271
#     y: 154
#   }
# }
# , description: "2018"
# bounding_poly {
#   vertices {
#     x: 288
#     y: 149
#   }
#   vertices {
#     x: 306
#     y: 149
#   }
#   vertices {
#     x: 306
#     y: 154
#   }
#   vertices {
#     x: 288
#     y: 154
#   }
# }
# , description: "Amaun"
# bounding_poly {
#   vertices {
#     x: 153
#     y: 164
#   }
#   vertices {
#     x: 180
#     y: 164
#   }
#   vertices {
#     x: 180
#     y: 170
#   }
#   vertices {
#     x: 153
#     y: 170
#   }
# }
# , description: "Bayar"
# bounding_poly {
#   vertices {
#     x: 230
#     y: 163
#   }
#   vertices {
#     x: 252
#     y: 163
#   }
#   vertices {
#     x: 252
#     y: 172
#   }
#   vertices {
#     x: 230
#     y: 172
#   }
# }
# , description: "Sebelum"
# bounding_poly {
#   vertices {
#     x: 256
#     y: 164
#   }
#   vertices {
#     x: 289
#     y: 163
#   }
#   vertices {
#     x: 289
#     y: 170
#   }
#   vertices {
#     x: 256
#     y: 171
#   }
# }
# , description: "Tunggakan"
# bounding_poly {
#   vertices {
#     x: 37
#     y: 175
#   }
#   vertices {
#     x: 77
#     y: 174
#   }
#   vertices {
#     x: 77
#     y: 182
#   }
#   vertices {
#     x: 37
#     y: 183
#   }
# }
# , description: "Caj"
# bounding_poly {
#   vertices {
#     x: 37
#     y: 185
#   }
#   vertices {
#     x: 49
#     y: 185
#   }
#   vertices {
#     x: 49
#     y: 193
#   }
#   vertices {
#     x: 37
#     y: 193
#   }
# }
# , description: "Semasa"
# bounding_poly {
#   vertices {
#     x: 52
#     y: 185
#   }
#   vertices {
#     x: 81
#     y: 184
#   }
#   vertices {
#     x: 81
#     y: 191
#   }
#   vertices {
#     x: 52
#     y: 192
#   }
# }
# , description: "Penggenapan"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 196
#   }
#   vertices {
#     x: 88
#     y: 196
#   }
#   vertices {
#     x: 88
#     y: 204
#   }
#   vertices {
#     x: 38
#     y: 204
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 142
#     y: 176
#   }
#   vertices {
#     x: 151
#     y: 176
#   }
#   vertices {
#     x: 151
#     y: 180
#   }
#   vertices {
#     x: 142
#     y: 180
#   }
# }
# , description: "0.00"
# bounding_poly {
#   vertices {
#     x: 174
#     y: 176
#   }
#   vertices {
#     x: 186
#     y: 176
#   }
#   vertices {
#     x: 186
#     y: 181
#   }
#   vertices {
#     x: 174
#     y: 181
#   }
# }
# , description: "Terima"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 175
#   }
#   vertices {
#     x: 251
#     y: 175
#   }
#   vertices {
#     x: 251
#     y: 180
#   }
#   vertices {
#     x: 231
#     y: 180
#   }
# }
# , description: "kasih"
# bounding_poly {
#   vertices {
#     x: 254
#     y: 175
#   }
#   vertices {
#     x: 270
#     y: 175
#   }
#   vertices {
#     x: 270
#     y: 180
#   }
#   vertices {
#     x: 254
#     y: 180
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 142
#     y: 186
#   }
#   vertices {
#     x: 151
#     y: 186
#   }
#   vertices {
#     x: 151
#     y: 190
#   }
#   vertices {
#     x: 142
#     y: 190
#   }
# }
# , description: "311.88"
# bounding_poly {
#   vertices {
#     x: 166
#     y: 186
#   }
#   vertices {
#     x: 186
#     y: 186
#   }
#   vertices {
#     x: 186
#     y: 192
#   }
#   vertices {
#     x: 166
#     y: 192
#   }
# }
# , description: "0,02"
# bounding_poly {
#   vertices {
#     x: 174
#     y: 195
#   }
#   vertices {
#     x: 187
#     y: 196
#   }
#   vertices {
#     x: 186
#     y: 203
#   }
#   vertices {
#     x: 173
#     y: 202
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 142
#     y: 197
#   }
#   vertices {
#     x: 151
#     y: 197
#   }
#   vertices {
#     x: 151
#     y: 202
#   }
#   vertices {
#     x: 142
#     y: 202
#   }
# }
# , description: "Jumlah"
# bounding_poly {
#   vertices {
#     x: 37
#     y: 207
#   }
#   vertices {
#     x: 65
#     y: 207
#   }
#   vertices {
#     x: 65
#     y: 212
#   }
#   vertices {
#     x: 37
#     y: 212
#   }
# }
# , description: "Bil"
# bounding_poly {
#   vertices {
#     x: 69
#     y: 207
#   }
#   vertices {
#     x: 78
#     y: 207
#   }
#   vertices {
#     x: 78
#     y: 212
#   }
#   vertices {
#     x: 69
#     y: 212
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 142
#     y: 207
#   }
#   vertices {
#     x: 151
#     y: 207
#   }
#   vertices {
#     x: 151
#     y: 212
#   }
#   vertices {
#     x: 142
#     y: 212
#   }
# }
# , description: "311.90"
# bounding_poly {
#   vertices {
#     x: 166
#     y: 208
#   }
#   vertices {
#     x: 186
#     y: 208
#   }
#   vertices {
#     x: 186
#     y: 213
#   }
#   vertices {
#     x: 166
#     y: 213
#   }
# }
# , description: "01.11.2018"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 207
#   }
#   vertices {
#     x: 265
#     y: 207
#   }
#   vertices {
#     x: 265
#     y: 213
#   }
#   vertices {
#     x: 231
#     y: 213
#   }
# }
# , description: "Amaun"
# bounding_poly {
#   vertices {
#     x: 153
#     y: 219
#   }
#   vertices {
#     x: 178
#     y: 220
#   }
#   vertices {
#     x: 178
#     y: 227
#   }
#   vertices {
#     x: 153
#     y: 226
#   }
# }
# , description: "52685"
# bounding_poly {
#   vertices {
#     x: 167
#     y: 230
#   }
#   vertices {
#     x: 187
#     y: 229
#   }
#   vertices {
#     x: 187
#     y: 236
#   }
#   vertices {
#     x: 167
#     y: 237
#   }
# }
# , description: "Tarikh"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 219
#   }
#   vertices {
#     x: 251
#     y: 219
#   }
#   vertices {
#     x: 251
#     y: 225
#   }
#   vertices {
#     x: 231
#     y: 225
#   }
# }
# , description: "5"
# bounding_poly {
#   vertices {
#     x: 3
#     y: 228
#   }
#   vertices {
#     x: 14
#     y: 228
#   }
#   vertices {
#     x: 14
#     y: 244
#   }
#   vertices {
#     x: 3
#     y: 244
#   }
# }
# , description: "Bil"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 230
#   }
#   vertices {
#     x: 45
#     y: 230
#   }
#   vertices {
#     x: 45
#     y: 236
#   }
#   vertices {
#     x: 38
#     y: 236
#   }
# }
# , description: "Terdahulu"
# bounding_poly {
#   vertices {
#     x: 49
#     y: 230
#   }
#   vertices {
#     x: 84
#     y: 230
#   }
#   vertices {
#     x: 84
#     y: 236
#   }
#   vertices {
#     x: 49
#     y: 236
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 141
#     y: 231
#   }
#   vertices {
#     x: 150
#     y: 231
#   }
#   vertices {
#     x: 150
#     y: 236
#   }
#   vertices {
#     x: 141
#     y: 236
#   }
# }
# , description: "02.08.2018"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 231
#   }
#   vertices {
#     x: 265
#     y: 231
#   }
#   vertices {
#     x: 265
#     y: 236
#   }
#   vertices {
#     x: 231
#     y: 236
#   }
# }
# , description: "Bayaran"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 241
#   }
#   vertices {
#     x: 67
#     y: 241
#   }
#   vertices {
#     x: 67
#     y: 248
#   }
#   vertices {
#     x: 38
#     y: 248
#   }
# }
# , description: "Akhir"
# bounding_poly {
#   vertices {
#     x: 70
#     y: 240
#   }
#   vertices {
#     x: 88
#     y: 240
#   }
#   vertices {
#     x: 88
#     y: 247
#   }
#   vertices {
#     x: 70
#     y: 247
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 141
#     y: 241
#   }
#   vertices {
#     x: 151
#     y: 241
#   }
#   vertices {
#     x: 151
#     y: 246
#   }
#   vertices {
#     x: 141
#     y: 246
#   }
# }
# , description: "526.85"
# bounding_poly {
#   vertices {
#     x: 167
#     y: 241
#   }
#   vertices {
#     x: 187
#     y: 241
#   }
#   vertices {
#     x: 187
#     y: 246
#   }
#   vertices {
#     x: 167
#     y: 246
#   }
# }
# , description: "30.08.2018"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 242
#   }
#   vertices {
#     x: 264
#     y: 242
#   }
#   vertices {
#     x: 264
#     y: 246
#   }
#   vertices {
#     x: 231
#     y: 246
#   }
# }
# , description: "Jenis"
# bounding_poly {
#   vertices {
#     x: 37
#     y: 255
#   }
#   vertices {
#     x: 56
#     y: 255
#   }
#   vertices {
#     x: 56
#     y: 261
#   }
#   vertices {
#     x: 37
#     y: 261
#   }
# }
# , description: "Bacaan"
# bounding_poly {
#   vertices {
#     x: 59
#     y: 255
#   }
#   vertices {
#     x: 86
#     y: 255
#   }
#   vertices {
#     x: 86
#     y: 261
#   }
#   vertices {
#     x: 59
#     y: 261
#   }
# }
# , description: "Bacaan"
# bounding_poly {
#   vertices {
#     x: 149
#     y: 255
#   }
#   vertices {
#     x: 178
#     y: 255
#   }
#   vertices {
#     x: 178
#     y: 261
#   }
#   vertices {
#     x: 149
#     y: 261
#   }
# }
# , description: "Sebenar"
# bounding_poly {
#   vertices {
#     x: 182
#     y: 255
#   }
#   vertices {
#     x: 216
#     y: 255
#   }
#   vertices {
#     x: 216
#     y: 261
#   }
#   vertices {
#     x: 182
#     y: 261
#   }
# }
# , description: "Tempoh"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 304
#   }
#   vertices {
#     x: 65
#     y: 304
#   }
#   vertices {
#     x: 65
#     y: 313
#   }
#   vertices {
#     x: 38
#     y: 313
#   }
# }
# , description: "Bil"
# bounding_poly {
#   vertices {
#     x: 69
#     y: 304
#   }
#   vertices {
#     x: 77
#     y: 304
#   }
#   vertices {
#     x: 77
#     y: 310
#   }
#   vertices {
#     x: 69
#     y: 310
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 85
#     y: 302
#   }
#   vertices {
#     x: 89
#     y: 302
#   }
#   vertices {
#     x: 89
#     y: 313
#   }
#   vertices {
#     x: 85
#     y: 313
#   }
# }
# , description: "03.09.2018"
# bounding_poly {
#   vertices {
#     x: 90
#     y: 305
#   }
#   vertices {
#     x: 124
#     y: 305
#   }
#   vertices {
#     x: 124
#     y: 310
#   }
#   vertices {
#     x: 90
#     y: 310
#   }
# }
# , description: "-"
# bounding_poly {
#   vertices {
#     x: 127
#     y: 308
#   }
#   vertices {
#     x: 128
#     y: 308
#   }
#   vertices {
#     x: 128
#     y: 308
#   }
#   vertices {
#     x: 127
#     y: 308
#   }
# }
# , description: "03.10.2018"
# bounding_poly {
#   vertices {
#     x: 131
#     y: 305
#   }
#   vertices {
#     x: 165
#     y: 305
#   }
#   vertices {
#     x: 165
#     y: 310
#   }
#   vertices {
#     x: 131
#     y: 310
#   }
# }
# , description: "(31"
# bounding_poly {
#   vertices {
#     x: 168
#     y: 305
#   }
#   vertices {
#     x: 175
#     y: 305
#   }
#   vertices {
#     x: 175
#     y: 311
#   }
#   vertices {
#     x: 168
#     y: 311
#   }
# }
# , description: "Hari)"
# bounding_poly {
#   vertices {
#     x: 179
#     y: 306
#   }
#   vertices {
#     x: 194
#     y: 306
#   }
#   vertices {
#     x: 194
#     y: 311
#   }
#   vertices {
#     x: 179
#     y: 311
#   }
# }
# , description: "Tarif"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 313
#   }
#   vertices {
#     x: 52
#     y: 313
#   }
#   vertices {
#     x: 52
#     y: 319
#   }
#   vertices {
#     x: 38
#     y: 319
#   }
# }
# , description: "Faktor"
# bounding_poly {
#   vertices {
#     x: 266
#     y: 304
#   }
#   vertices {
#     x: 288
#     y: 304
#   }
#   vertices {
#     x: 288
#     y: 310
#   }
#   vertices {
#     x: 266
#     y: 310
#   }
# }
# , description: "Prorata"
# bounding_poly {
#   vertices {
#     x: 291
#     y: 304
#   }
#   vertices {
#     x: 317
#     y: 304
#   }
#   vertices {
#     x: 317
#     y: 311
#   }
#   vertices {
#     x: 291
#     y: 311
#   }
# }
# , description: ":A:"
# bounding_poly {
#   vertices {
#     x: 87
#     y: 312
#   }
#   vertices {
#     x: 101
#     y: 312
#   }
#   vertices {
#     x: 101
#     y: 319
#   }
#   vertices {
#     x: 87
#     y: 319
#   }
# }
# , description: "Kediaman"
# bounding_poly {
#   vertices {
#     x: 103
#     y: 312
#   }
#   vertices {
#     x: 131
#     y: 312
#   }
#   vertices {
#     x: 131
#     y: 319
#   }
#   vertices {
#     x: 103
#     y: 319
#   }
# }
# , description: "1,00000"
# bounding_poly {
#   vertices {
#     x: 277
#     y: 314
#   }
#   vertices {
#     x: 300
#     y: 314
#   }
#   vertices {
#     x: 300
#     y: 319
#   }
#   vertices {
#     x: 277
#     y: 319
#   }
# }
# , description: "Blok"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 327
#   }
#   vertices {
#     x: 52
#     y: 327
#   }
#   vertices {
#     x: 52
#     y: 332
#   }
#   vertices {
#     x: 38
#     y: 332
#   }
# }
# , description: "Tarif"
# bounding_poly {
#   vertices {
#     x: 56
#     y: 326
#   }
#   vertices {
#     x: 70
#     y: 326
#   }
#   vertices {
#     x: 70
#     y: 333
#   }
#   vertices {
#     x: 56
#     y: 333
#   }
# }
# , description: "(KWh)"
# bounding_poly {
#   vertices {
#     x: 74
#     y: 327
#   }
#   vertices {
#     x: 95
#     y: 327
#   }
#   vertices {
#     x: 95
#     y: 334
#   }
#   vertices {
#     x: 74
#     y: 334
#   }
# }
# , description: "200"
# bounding_poly {
#   vertices {
#     x: 58
#     y: 336
#   }
#   vertices {
#     x: 69
#     y: 336
#   }
#   vertices {
#     x: 69
#     y: 341
#   }
#   vertices {
#     x: 58
#     y: 341
#   }
# }
# , description: "100"
# bounding_poly {
#   vertices {
#     x: 59
#     y: 345
#   }
#   vertices {
#     x: 69
#     y: 345
#   }
#   vertices {
#     x: 69
#     y: 350
#   }
#   vertices {
#     x: 59
#     y: 350
#   }
# }
# , description: "300"
# bounding_poly {
#   vertices {
#     x: 58
#     y: 353
#   }
#   vertices {
#     x: 69
#     y: 353
#   }
#   vertices {
#     x: 69
#     y: 358
#   }
#   vertices {
#     x: 58
#     y: 358
#   }
# }
# , description: "300"
# bounding_poly {
#   vertices {
#     x: 58
#     y: 362
#   }
#   vertices {
#     x: 69
#     y: 362
#   }
#   vertices {
#     x: 69
#     y: 367
#   }
#   vertices {
#     x: 58
#     y: 367
#   }
# }
# , description: "Blok"
# bounding_poly {
#   vertices {
#     x: 114
#     y: 327
#   }
#   vertices {
#     x: 128
#     y: 327
#   }
#   vertices {
#     x: 128
#     y: 332
#   }
#   vertices {
#     x: 114
#     y: 332
#   }
# }
# , description: "Prorata"
# bounding_poly {
#   vertices {
#     x: 132
#     y: 326
#   }
#   vertices {
#     x: 158
#     y: 326
#   }
#   vertices {
#     x: 158
#     y: 333
#   }
#   vertices {
#     x: 132
#     y: 333
#   }
# }
# , description: "(kWh)"
# bounding_poly {
#   vertices {
#     x: 161
#     y: 327
#   }
#   vertices {
#     x: 182
#     y: 327
#   }
#   vertices {
#     x: 182
#     y: 334
#   }
#   vertices {
#     x: 161
#     y: 334
#   }
# }
# , description: "200"
# bounding_poly {
#   vertices {
#     x: 135
#     y: 336
#   }
#   vertices {
#     x: 145
#     y: 336
#   }
#   vertices {
#     x: 145
#     y: 341
#   }
#   vertices {
#     x: 135
#     y: 341
#   }
# }
# , description: "100"
# bounding_poly {
#   vertices {
#     x: 136
#     y: 345
#   }
#   vertices {
#     x: 145
#     y: 345
#   }
#   vertices {
#     x: 145
#     y: 350
#   }
#   vertices {
#     x: 136
#     y: 350
#   }
# }
# , description: "300"
# bounding_poly {
#   vertices {
#     x: 135
#     y: 353
#   }
#   vertices {
#     x: 146
#     y: 353
#   }
#   vertices {
#     x: 146
#     y: 358
#   }
#   vertices {
#     x: 135
#     y: 358
#   }
# }
# , description: "130"
# bounding_poly {
#   vertices {
#     x: 135
#     y: 362
#   }
#   vertices {
#     x: 145
#     y: 362
#   }
#   vertices {
#     x: 145
#     y: 367
#   }
#   vertices {
#     x: 135
#     y: 367
#   }
# }
# , description: "Kadar"
# bounding_poly {
#   vertices {
#     x: 202
#     y: 327
#   }
#   vertices {
#     x: 223
#     y: 327
#   }
#   vertices {
#     x: 223
#     y: 333
#   }
#   vertices {
#     x: 202
#     y: 333
#   }
# }
# , description: "(RM)"
# bounding_poly {
#   vertices {
#     x: 227
#     y: 327
#   }
#   vertices {
#     x: 244
#     y: 327
#   }
#   vertices {
#     x: 244
#     y: 334
#   }
#   vertices {
#     x: 227
#     y: 334
#   }
# }
# , description: "0.218"
# bounding_poly {
#   vertices {
#     x: 212
#     y: 336
#   }
#   vertices {
#     x: 228
#     y: 336
#   }
#   vertices {
#     x: 228
#     y: 341
#   }
#   vertices {
#     x: 212
#     y: 341
#   }
# }
# , description: "Amaun"
# bounding_poly {
#   vertices {
#     x: 268
#     y: 327
#   }
#   vertices {
#     x: 293
#     y: 327
#   }
#   vertices {
#     x: 293
#     y: 332
#   }
#   vertices {
#     x: 268
#     y: 332
#   }
# }
# , description: "(RM)"
# bounding_poly {
#   vertices {
#     x: 297
#     y: 327
#   }
#   vertices {
#     x: 314
#     y: 327
#   }
#   vertices {
#     x: 314
#     y: 334
#   }
#   vertices {
#     x: 297
#     y: 334
#   }
# }
# , description: "43.60"
# bounding_poly {
#   vertices {
#     x: 282
#     y: 336
#   }
#   vertices {
#     x: 298
#     y: 336
#   }
#   vertices {
#     x: 298
#     y: 341
#   }
#   vertices {
#     x: 282
#     y: 341
#   }
# }
# , description: "33.40"
# bounding_poly {
#   vertices {
#     x: 282
#     y: 345
#   }
#   vertices {
#     x: 298
#     y: 345
#   }
#   vertices {
#     x: 298
#     y: 350
#   }
#   vertices {
#     x: 282
#     y: 350
#   }
# }
# , description: "154.80"
# bounding_poly {
#   vertices {
#     x: 279
#     y: 353
#   }
#   vertices {
#     x: 299
#     y: 353
#   }
#   vertices {
#     x: 299
#     y: 358
#   }
#   vertices {
#     x: 279
#     y: 358
#   }
# }
# , description: "70.98"
# bounding_poly {
#   vertices {
#     x: 283
#     y: 362
#   }
#   vertices {
#     x: 299
#     y: 362
#   }
#   vertices {
#     x: 299
#     y: 367
#   }
#   vertices {
#     x: 283
#     y: 367
#   }
# }
# , description: "8"
# bounding_poly {
#   vertices {
#     x: 9
#     y: 343
#   }
#   vertices {
#     x: 14
#     y: 343
#   }
#   vertices {
#     x: 14
#     y: 350
#   }
#   vertices {
#     x: 9
#     y: 350
#   }
# }
# , description: "0.334"
# bounding_poly {
#   vertices {
#     x: 212
#     y: 345
#   }
#   vertices {
#     x: 228
#     y: 345
#   }
#   vertices {
#     x: 228
#     y: 349
#   }
#   vertices {
#     x: 212
#     y: 349
#   }
# }
# , description: "0.516"
# bounding_poly {
#   vertices {
#     x: 212
#     y: 353
#   }
#   vertices {
#     x: 228
#     y: 353
#   }
#   vertices {
#     x: 228
#     y: 358
#   }
#   vertices {
#     x: 212
#     y: 358
#   }
# }
# , description: "0.546"
# bounding_poly {
#   vertices {
#     x: 212
#     y: 362
#   }
#   vertices {
#     x: 228
#     y: 362
#   }
#   vertices {
#     x: 228
#     y: 367
#   }
#   vertices {
#     x: 212
#     y: 367
#   }
# }
# , description: "Jumlah"
# bounding_poly {
#   vertices {
#     x: 52
#     y: 377
#   }
#   vertices {
#     x: 74
#     y: 376
#   }
#   vertices {
#     x: 74
#     y: 382
#   }
#   vertices {
#     x: 52
#     y: 383
#   }
# }
# , description: "730"
# bounding_poly {
#   vertices {
#     x: 135
#     y: 378
#   }
#   vertices {
#     x: 146
#     y: 378
#   }
#   vertices {
#     x: 146
#     y: 383
#   }
#   vertices {
#     x: 135
#     y: 383
#   }
# }
# , description: "302.78"
# bounding_poly {
#   vertices {
#     x: 279
#     y: 378
#   }
#   vertices {
#     x: 298
#     y: 378
#   }
#   vertices {
#     x: 298
#     y: 383
#   }
#   vertices {
#     x: 279
#     y: 383
#   }
# }
# , description: "Tidak"
# bounding_poly {
#   vertices {
#     x: 193
#     y: 430
#   }
#   vertices {
#     x: 212
#     y: 430
#   }
#   vertices {
#     x: 212
#     y: 440
#   }
#   vertices {
#     x: 193
#     y: 440
#   }
# }
# , description: "Kena"
# bounding_poly {
#   vertices {
#     x: 216
#     y: 430
#   }
#   vertices {
#     x: 236
#     y: 430
#   }
#   vertices {
#     x: 236
#     y: 440
#   }
#   vertices {
#     x: 216
#     y: 440
#   }
# }
# , description: "ST"
# bounding_poly {
#   vertices {
#     x: 209
#     y: 440
#   }
#   vertices {
#     x: 219
#     y: 440
#   }
#   vertices {
#     x: 219
#     y: 446
#   }
#   vertices {
#     x: 209
#     y: 446
#   }
# }
# , description: "Kena"
# bounding_poly {
#   vertices {
#     x: 252
#     y: 431
#   }
#   vertices {
#     x: 271
#     y: 431
#   }
#   vertices {
#     x: 271
#     y: 437
#   }
#   vertices {
#     x: 252
#     y: 437
#   }
# }
# , description: "ST"
# bounding_poly {
#   vertices {
#     x: 255
#     y: 440
#   }
#   vertices {
#     x: 265
#     y: 440
#   }
#   vertices {
#     x: 265
#     y: 446
#   }
#   vertices {
#     x: 255
#     y: 446
#   }
# }
# , description: "Keterangan"
# bounding_poly {
#   vertices {
#     x: 85
#     y: 432
#   }
#   vertices {
#     x: 129
#     y: 432
#   }
#   vertices {
#     x: 129
#     y: 439
#   }
#   vertices {
#     x: 85
#     y: 439
#   }
# }
# , description: "Jumlah"
# bounding_poly {
#   vertices {
#     x: 296
#     y: 431
#   }
#   vertices {
#     x: 324
#     y: 431
#   }
#   vertices {
#     x: 324
#     y: 437
#   }
#   vertices {
#     x: 296
#     y: 437
#   }
# }
# , description: "Kegunaan"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 452
#   }
#   vertices {
#     x: 74
#     y: 452
#   }
#   vertices {
#     x: 74
#     y: 459
#   }
#   vertices {
#     x: 38
#     y: 459
#   }
# }
# , description: "kWh"
# bounding_poly {
#   vertices {
#     x: 77
#     y: 451
#   }
#   vertices {
#     x: 93
#     y: 451
#   }
#   vertices {
#     x: 93
#     y: 457
#   }
#   vertices {
#     x: 77
#     y: 457
#   }
# }
# , description: "Kegunaan"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 463
#   }
#   vertices {
#     x: 74
#     y: 463
#   }
#   vertices {
#     x: 74
#     y: 470
#   }
#   vertices {
#     x: 38
#     y: 470
#   }
# }
# , description: "kWh"
# bounding_poly {
#   vertices {
#     x: 171
#     y: 452
#   }
#   vertices {
#     x: 186
#     y: 452
#   }
#   vertices {
#     x: 186
#     y: 457
#   }
#   vertices {
#     x: 171
#     y: 457
#   }
# }
# , description: "600"
# bounding_poly {
#   vertices {
#     x: 209
#     y: 453
#   }
#   vertices {
#     x: 220
#     y: 453
#   }
#   vertices {
#     x: 220
#     y: 457
#   }
#   vertices {
#     x: 209
#     y: 457
#   }
# }
# , description: "130"
# bounding_poly {
#   vertices {
#     x: 256
#     y: 452
#   }
#   vertices {
#     x: 267
#     y: 452
#   }
#   vertices {
#     x: 267
#     y: 457
#   }
#   vertices {
#     x: 256
#     y: 457
#   }
# }
# , description: "730"
# bounding_poly {
#   vertices {
#     x: 306
#     y: 452
#   }
#   vertices {
#     x: 316
#     y: 452
#   }
#   vertices {
#     x: 316
#     y: 457
#   }
#   vertices {
#     x: 306
#     y: 457
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 175
#     y: 462
#   }
#   vertices {
#     x: 186
#     y: 462
#   }
#   vertices {
#     x: 186
#     y: 468
#   }
#   vertices {
#     x: 175
#     y: 468
#   }
# }
# , description: "231.80"
# bounding_poly {
#   vertices {
#     x: 204
#     y: 463
#   }
#   vertices {
#     x: 224
#     y: 463
#   }
#   vertices {
#     x: 224
#     y: 468
#   }
#   vertices {
#     x: 204
#     y: 468
#   }
# }
# , description: "70.98"
# bounding_poly {
#   vertices {
#     x: 254
#     y: 464
#   }
#   vertices {
#     x: 270
#     y: 464
#   }
#   vertices {
#     x: 270
#     y: 469
#   }
#   vertices {
#     x: 254
#     y: 469
#   }
# }
# , description: "302.78"
# bounding_poly {
#   vertices {
#     x: 301
#     y: 464
#   }
#   vertices {
#     x: 320
#     y: 464
#   }
#   vertices {
#     x: 320
#     y: 469
#   }
#   vertices {
#     x: 301
#     y: 469
#   }
# }
# , description: "Kegunaan"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 538
#   }
#   vertices {
#     x: 74
#     y: 538
#   }
#   vertices {
#     x: 74
#     y: 545
#   }
#   vertices {
#     x: 38
#     y: 545
#   }
# }
# , description: "Bulan"
# bounding_poly {
#   vertices {
#     x: 78
#     y: 537
#   }
#   vertices {
#     x: 97
#     y: 537
#   }
#   vertices {
#     x: 97
#     y: 544
#   }
#   vertices {
#     x: 78
#     y: 544
#   }
# }
# , description: "Semasa"
# bounding_poly {
#   vertices {
#     x: 101
#     y: 537
#   }
#   vertices {
#     x: 130
#     y: 537
#   }
#   vertices {
#     x: 130
#     y: 544
#   }
#   vertices {
#     x: 101
#     y: 544
#   }
# }
# , description: "Service"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 548
#   }
#   vertices {
#     x: 60
#     y: 548
#   }
#   vertices {
#     x: 60
#     y: 553
#   }
#   vertices {
#     x: 38
#     y: 553
#   }
# }
# , description: "Tax"
# bounding_poly {
#   vertices {
#     x: 62
#     y: 548
#   }
#   vertices {
#     x: 72
#     y: 548
#   }
#   vertices {
#     x: 72
#     y: 553
#   }
#   vertices {
#     x: 62
#     y: 553
#   }
# }
# , description: "(66)"
# bounding_poly {
#   vertices {
#     x: 75
#     y: 548
#   }
#   vertices {
#     x: 88
#     y: 548
#   }
#   vertices {
#     x: 88
#     y: 554
#   }
#   vertices {
#     x: 75
#     y: 554
#   }
# }
# , description: "KWTBB"
# bounding_poly {
#   vertices {
#     x: 38
#     y: 557
#   }
#   vertices {
#     x: 60
#     y: 557
#   }
#   vertices {
#     x: 60
#     y: 562
#   }
#   vertices {
#     x: 38
#     y: 562
#   }
# }
# , description: "(1.6%)"
# bounding_poly {
#   vertices {
#     x: 63
#     y: 557
#   }
#   vertices {
#     x: 82
#     y: 557
#   }
#   vertices {
#     x: 82
#     y: 563
#   }
#   vertices {
#     x: 63
#     y: 563
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 175
#     y: 538
#   }
#   vertices {
#     x: 186
#     y: 538
#   }
#   vertices {
#     x: 186
#     y: 543
#   }
#   vertices {
#     x: 175
#     y: 543
#   }
# }
# , description: "231.80"
# bounding_poly {
#   vertices {
#     x: 206
#     y: 539
#   }
#   vertices {
#     x: 226
#     y: 539
#   }
#   vertices {
#     x: 226
#     y: 544
#   }
#   vertices {
#     x: 206
#     y: 544
#   }
# }
# , description: "70.98"
# bounding_poly {
#   vertices {
#     x: 254
#     y: 539
#   }
#   vertices {
#     x: 270
#     y: 539
#   }
#   vertices {
#     x: 270
#     y: 544
#   }
#   vertices {
#     x: 254
#     y: 544
#   }
# }
# , description: "302.78"
# bounding_poly {
#   vertices {
#     x: 300
#     y: 539
#   }
#   vertices {
#     x: 320
#     y: 539
#   }
#   vertices {
#     x: 320
#     y: 544
#   }
#   vertices {
#     x: 300
#     y: 544
#   }
# }
# , description: "4.26"
# bounding_poly {
#   vertices {
#     x: 308
#     y: 547
#   }
#   vertices {
#     x: 320
#     y: 547
#   }
#   vertices {
#     x: 320
#     y: 552
#   }
#   vertices {
#     x: 308
#     y: 552
#   }
# }
# , description: "4.84"
# bounding_poly {
#   vertices {
#     x: 308
#     y: 556
#   }
#   vertices {
#     x: 320
#     y: 556
#   }
#   vertices {
#     x: 320
#     y: 561
#   }
#   vertices {
#     x: 308
#     y: 561
#   }
# }
# , description: "10"
# bounding_poly {
#   vertices {
#     x: 1
#     y: 602
#   }
#   vertices {
#     x: 16
#     y: 602
#   }
#   vertices {
#     x: 16
#     y: 612
#   }
#   vertices {
#     x: 1
#     y: 612
#   }
# }
# , description: "Caj"
# bounding_poly {
#   vertices {
#     x: 37
#     y: 602
#   }
#   vertices {
#     x: 49
#     y: 602
#   }
#   vertices {
#     x: 49
#     y: 610
#   }
#   vertices {
#     x: 37
#     y: 610
#   }
# }
# , description: "Semasa"
# bounding_poly {
#   vertices {
#     x: 52
#     y: 601
#   }
#   vertices {
#     x: 81
#     y: 601
#   }
#   vertices {
#     x: 81
#     y: 609
#   }
#   vertices {
#     x: 52
#     y: 609
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 175
#     y: 602
#   }
#   vertices {
#     x: 186
#     y: 602
#   }
#   vertices {
#     x: 186
#     y: 608
#   }
#   vertices {
#     x: 175
#     y: 608
#   }
# }
# , description: "311.88"
# bounding_poly {
#   vertices {
#     x: 301
#     y: 603
#   }
#   vertices {
#     x: 320
#     y: 603
#   }
#   vertices {
#     x: 320
#     y: 608
#   }
#   vertices {
#     x: 301
#     y: 608
#   }
# }
# , description: "Bacaan"
# bounding_poly {
#   vertices {
#     x: 152
#     y: 618
#   }
#   vertices {
#     x: 179
#     y: 618
#   }
#   vertices {
#     x: 179
#     y: 624
#   }
#   vertices {
#     x: 152
#     y: 624
#   }
# }
# , description: "Meter"
# bounding_poly {
#   vertices {
#     x: 182
#     y: 618
#   }
#   vertices {
#     x: 202
#     y: 618
#   }
#   vertices {
#     x: 202
#     y: 624
#   }
#   vertices {
#     x: 182
#     y: 624
#   }
# }
# , description: "No"
# bounding_poly {
#   vertices {
#     x: 52
#     y: 624
#   }
#   vertices {
#     x: 61
#     y: 624
#   }
#   vertices {
#     x: 61
#     y: 630
#   }
#   vertices {
#     x: 52
#     y: 630
#   }
# }
# , description: "Meter"
# bounding_poly {
#   vertices {
#     x: 65
#     y: 624
#   }
#   vertices {
#     x: 85
#     y: 624
#   }
#   vertices {
#     x: 85
#     y: 630
#   }
#   vertices {
#     x: 65
#     y: 630
#   }
# }
# , description: "\320\232egunaan"
# bounding_poly {
#   vertices {
#     x: 251
#     y: 623
#   }
#   vertices {
#     x: 287
#     y: 622
#   }
#   vertices {
#     x: 287
#     y: 631
#   }
#   vertices {
#     x: 251
#     y: 632
#   }
# }
# , description: "Unit"
# bounding_poly {
#   vertices {
#     x: 310
#     y: 624
#   }
#   vertices {
#     x: 324
#     y: 624
#   }
#   vertices {
#     x: 324
#     y: 630
#   }
#   vertices {
#     x: 310
#     y: 630
#   }
# }
# , description: "Dahulu"
# bounding_poly {
#   vertices {
#     x: 131
#     y: 630
#   }
#   vertices {
#     x: 156
#     y: 630
#   }
#   vertices {
#     x: 156
#     y: 636
#   }
#   vertices {
#     x: 131
#     y: 636
#   }
# }
# , description: "Semasa"
# bounding_poly {
#   vertices {
#     x: 194
#     y: 630
#   }
#   vertices {
#     x: 223
#     y: 630
#   }
#   vertices {
#     x: 223
#     y: 636
#   }
#   vertices {
#     x: 194
#     y: 636
#   }
# }
# , description: "311201234"
# bounding_poly {
#   vertices {
#     x: 50
#     y: 647
#   }
#   vertices {
#     x: 84
#     y: 647
#   }
#   vertices {
#     x: 84
#     y: 652
#   }
#   vertices {
#     x: 50
#     y: 652
#   }
# }
# , description: "28470"
# bounding_poly {
#   vertices {
#     x: 135
#     y: 647
#   }
#   vertices {
#     x: 153
#     y: 647
#   }
#   vertices {
#     x: 153
#     y: 652
#   }
#   vertices {
#     x: 135
#     y: 652
#   }
# }
# , description: "29200"
# bounding_poly {
#   vertices {
#     x: 200
#     y: 647
#   }
#   vertices {
#     x: 218
#     y: 647
#   }
#   vertices {
#     x: 218
#     y: 652
#   }
#   vertices {
#     x: 200
#     y: 652
#   }
# }
# , description: "730"
# bounding_poly {
#   vertices {
#     x: 265
#     y: 647
#   }
#   vertices {
#     x: 275
#     y: 647
#   }
#   vertices {
#     x: 275
#     y: 652
#   }
#   vertices {
#     x: 265
#     y: 652
#   }
# }
# , description: "kWh"
# bounding_poly {
#   vertices {
#     x: 311
#     y: 647
#   }
#   vertices {
#     x: 324
#     y: 647
#   }
#   vertices {
#     x: 324
#     y: 652
#   }
#   vertices {
#     x: 311
#     y: 652
#   }
# }
# , description: "Subsidi"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 682
#   }
#   vertices {
#     x: 51
#     y: 682
#   }
#   vertices {
#     x: 51
#     y: 687
#   }
#   vertices {
#     x: 29
#     y: 687
#   }
# }
# , description: "1.35"
# bounding_poly {
#   vertices {
#     x: 55
#     y: 683
#   }
#   vertices {
#     x: 66
#     y: 683
#   }
#   vertices {
#     x: 66
#     y: 687
#   }
#   vertices {
#     x: 55
#     y: 687
#   }
# }
# , description: "sen/kWh"
# bounding_poly {
#   vertices {
#     x: 69
#     y: 682
#   }
#   vertices {
#     x: 96
#     y: 682
#   }
#   vertices {
#     x: 96
#     y: 687
#   }
#   vertices {
#     x: 69
#     y: 687
#   }
# }
# , description: "diblayai"
# bounding_poly {
#   vertices {
#     x: 99
#     y: 682
#   }
#   vertices {
#     x: 123
#     y: 682
#   }
#   vertices {
#     x: 123
#     y: 689
#   }
#   vertices {
#     x: 99
#     y: 689
#   }
# }
# , description: "Kerajaan"
# bounding_poly {
#   vertices {
#     x: 126
#     y: 683
#   }
#   vertices {
#     x: 152
#     y: 683
#   }
#   vertices {
#     x: 152
#     y: 689
#   }
#   vertices {
#     x: 126
#     y: 689
#   }
# }
# , description: "Persekutuan"
# bounding_poly {
#   vertices {
#     x: 155
#     y: 682
#   }
#   vertices {
#     x: 194
#     y: 682
#   }
#   vertices {
#     x: 194
#     y: 687
#   }
#   vertices {
#     x: 155
#     y: 687
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 197
#     y: 682
#   }
#   vertices {
#     x: 206
#     y: 682
#   }
#   vertices {
#     x: 206
#     y: 687
#   }
#   vertices {
#     x: 197
#     y: 687
#   }
# }
# , description: "10.61"
# bounding_poly {
#   vertices {
#     x: 209
#     y: 683
#   }
#   vertices {
#     x: 224
#     y: 683
#   }
#   vertices {
#     x: 224
#     y: 687
#   }
#   vertices {
#     x: 209
#     y: 687
#   }
# }
# , description: "Service"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 696
#   }
#   vertices {
#     x: 51
#     y: 696
#   }
#   vertices {
#     x: 51
#     y: 701
#   }
#   vertices {
#     x: 29
#     y: 701
#   }
# }
# , description: "Tax"
# bounding_poly {
#   vertices {
#     x: 53
#     y: 696
#   }
#   vertices {
#     x: 63
#     y: 696
#   }
#   vertices {
#     x: 63
#     y: 701
#   }
#   vertices {
#     x: 53
#     y: 701
#   }
# }
# , description: "(ST)"
# bounding_poly {
#   vertices {
#     x: 66
#     y: 696
#   }
#   vertices {
#     x: 77
#     y: 696
#   }
#   vertices {
#     x: 77
#     y: 702
#   }
#   vertices {
#     x: 66
#     y: 702
#   }
# }
# , description: "6%"
# bounding_poly {
#   vertices {
#     x: 80
#     y: 696
#   }
#   vertices {
#     x: 89
#     y: 696
#   }
#   vertices {
#     x: 89
#     y: 701
#   }
#   vertices {
#     x: 80
#     y: 701
#   }
# }
# , description: "bagi"
# bounding_poly {
#   vertices {
#     x: 92
#     y: 696
#   }
#   vertices {
#     x: 105
#     y: 696
#   }
#   vertices {
#     x: 105
#     y: 703
#   }
#   vertices {
#     x: 92
#     y: 703
#   }
# }
# , description: "penggunaan"
# bounding_poly {
#   vertices {
#     x: 107
#     y: 696
#   }
#   vertices {
#     x: 147
#     y: 696
#   }
#   vertices {
#     x: 147
#     y: 703
#   }
#   vertices {
#     x: 107
#     y: 703
#   }
# }
# , description: "Domestik"
# bounding_poly {
#   vertices {
#     x: 150
#     y: 695
#   }
#   vertices {
#     x: 180
#     y: 695
#   }
#   vertices {
#     x: 180
#     y: 701
#   }
#   vertices {
#     x: 150
#     y: 701
#   }
# }
# , description: "melebihi"
# bounding_poly {
#   vertices {
#     x: 183
#     y: 696
#   }
#   vertices {
#     x: 210
#     y: 696
#   }
#   vertices {
#     x: 210
#     y: 701
#   }
#   vertices {
#     x: 183
#     y: 701
#   }
# }
# , description: "600"
# bounding_poly {
#   vertices {
#     x: 212
#     y: 696
#   }
#   vertices {
#     x: 223
#     y: 696
#   }
#   vertices {
#     x: 223
#     y: 701
#   }
#   vertices {
#     x: 212
#     y: 701
#   }
# }
# , description: "kWh"
# bounding_poly {
#   vertices {
#     x: 226
#     y: 696
#   }
#   vertices {
#     x: 239
#     y: 696
#   }
#   vertices {
#     x: 239
#     y: 701
#   }
#   vertices {
#     x: 226
#     y: 701
#   }
# }
# , description: "Bayaran"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 709
#   }
#   vertices {
#     x: 53
#     y: 709
#   }
#   vertices {
#     x: 53
#     y: 715
#   }
#   vertices {
#     x: 29
#     y: 715
#   }
# }
# , description: "melalui"
# bounding_poly {
#   vertices {
#     x: 56
#     y: 709
#   }
#   vertices {
#     x: 79
#     y: 709
#   }
#   vertices {
#     x: 79
#     y: 714
#   }
#   vertices {
#     x: 56
#     y: 714
#   }
# }
# , description: "cek"
# bounding_poly {
#   vertices {
#     x: 81
#     y: 709
#   }
#   vertices {
#     x: 91
#     y: 709
#   }
#   vertices {
#     x: 91
#     y: 714
#   }
#   vertices {
#     x: 81
#     y: 714
#   }
# }
# , description: "sah"
# bounding_poly {
#   vertices {
#     x: 94
#     y: 709
#   }
#   vertices {
#     x: 104
#     y: 709
#   }
#   vertices {
#     x: 104
#     y: 714
#   }
#   vertices {
#     x: 94
#     y: 714
#   }
# }
# , description: "setelah"
# bounding_poly {
#   vertices {
#     x: 107
#     y: 709
#   }
#   vertices {
#     x: 129
#     y: 709
#   }
#   vertices {
#     x: 129
#     y: 714
#   }
#   vertices {
#     x: 107
#     y: 714
#   }
# }
# , description: "penjelasan"
# bounding_poly {
#   vertices {
#     x: 132
#     y: 708
#   }
#   vertices {
#     x: 165
#     y: 708
#   }
#   vertices {
#     x: 165
#     y: 716
#   }
#   vertices {
#     x: 132
#     y: 716
#   }
# }
# , description: "cek"
# bounding_poly {
#   vertices {
#     x: 168
#     y: 709
#   }
#   vertices {
#     x: 178
#     y: 709
#   }
#   vertices {
#     x: 178
#     y: 714
#   }
#   vertices {
#     x: 168
#     y: 714
#   }
# }
# , description: "oleh"
# bounding_poly {
#   vertices {
#     x: 180
#     y: 708
#   }
#   vertices {
#     x: 193
#     y: 708
#   }
#   vertices {
#     x: 193
#     y: 714
#   }
#   vertices {
#     x: 180
#     y: 714
#   }
# }
# , description: "bank"
# bounding_poly {
#   vertices {
#     x: 196
#     y: 709
#   }
#   vertices {
#     x: 211
#     y: 709
#   }
#   vertices {
#     x: 211
#     y: 714
#   }
#   vertices {
#     x: 196
#     y: 714
#   }
# }
# , description: "*22000123451200010001234000000000031190"
# bounding_poly {
#   vertices {
#     x: 92
#     y: 763
#   }
#   vertices {
#     x: 265
#     y: 763
#   }
#   vertices {
#     x: 265
#     y: 773
#   }
#   vertices {
#     x: 92
#     y: 773
#   }
# }
# , description: "Ali"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 790
#   }
#   vertices {
#     x: 37
#     y: 790
#   }
#   vertices {
#     x: 37
#     y: 795
#   }
#   vertices {
#     x: 29
#     y: 795
#   }
# }
# , description: "bin"
# bounding_poly {
#   vertices {
#     x: 39
#     y: 790
#   }
#   vertices {
#     x: 48
#     y: 790
#   }
#   vertices {
#     x: 48
#     y: 795
#   }
#   vertices {
#     x: 39
#     y: 795
#   }
# }
# , description: "Abu"
# bounding_poly {
#   vertices {
#     x: 51
#     y: 790
#   }
#   vertices {
#     x: 63
#     y: 790
#   }
#   vertices {
#     x: 63
#     y: 795
#   }
#   vertices {
#     x: 51
#     y: 795
#   }
# }
# , description: "E2SA"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 801
#   }
#   vertices {
#     x: 42
#     y: 801
#   }
#   vertices {
#     x: 42
#     y: 805
#   }
#   vertices {
#     x: 29
#     y: 805
#   }
# }
# , description: "-"
# bounding_poly {
#   vertices {
#     x: 45
#     y: 800
#   }
#   vertices {
#     x: 47
#     y: 800
#   }
#   vertices {
#     x: 47
#     y: 807
#   }
#   vertices {
#     x: 45
#     y: 807
#   }
# }
# , description: "201"
# bounding_poly {
#   vertices {
#     x: 48
#     y: 801
#   }
#   vertices {
#     x: 56
#     y: 801
#   }
#   vertices {
#     x: 56
#     y: 805
#   }
#   vertices {
#     x: 48
#     y: 805
#   }
# }
# , description: "Sek"
# bounding_poly {
#   vertices {
#     x: 60
#     y: 801
#   }
#   vertices {
#     x: 68
#     y: 801
#   }
#   vertices {
#     x: 68
#     y: 806
#   }
#   vertices {
#     x: 60
#     y: 806
#   }
# }
# , description: "3"
# bounding_poly {
#   vertices {
#     x: 71
#     y: 801
#   }
#   vertices {
#     x: 73
#     y: 801
#   }
#   vertices {
#     x: 73
#     y: 806
#   }
#   vertices {
#     x: 71
#     y: 806
#   }
# }
# , description: "Wangsa"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 810
#   }
#   vertices {
#     x: 50
#     y: 810
#   }
#   vertices {
#     x: 50
#     y: 816
#   }
#   vertices {
#     x: 29
#     y: 816
#   }
# }
# , description: "Maju"
# bounding_poly {
#   vertices {
#     x: 52
#     y: 810
#   }
#   vertices {
#     x: 65
#     y: 810
#   }
#   vertices {
#     x: 65
#     y: 816
#   }
#   vertices {
#     x: 52
#     y: 816
#   }
# }
# , description: "53300"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 819
#   }
#   vertices {
#     x: 45
#     y: 819
#   }
#   vertices {
#     x: 45
#     y: 823
#   }
#   vertices {
#     x: 29
#     y: 823
#   }
# }
# , description: "WP"
# bounding_poly {
#   vertices {
#     x: 29
#     y: 827
#   }
#   vertices {
#     x: 37
#     y: 827
#   }
#   vertices {
#     x: 37
#     y: 832
#   }
#   vertices {
#     x: 29
#     y: 832
#   }
# }
# , description: "Kuala"
# bounding_poly {
#   vertices {
#     x: 40
#     y: 827
#   }
#   vertices {
#     x: 54
#     y: 827
#   }
#   vertices {
#     x: 54
#     y: 833
#   }
#   vertices {
#     x: 40
#     y: 833
#   }
# }
# , description: "Lumpur"
# bounding_poly {
#   vertices {
#     x: 56
#     y: 828
#   }
#   vertices {
#     x: 77
#     y: 828
#   }
#   vertices {
#     x: 77
#     y: 833
#   }
#   vertices {
#     x: 56
#     y: 833
#   }
# }
# , description: "RM"
# bounding_poly {
#   vertices {
#     x: 268
#     y: 826
#   }
#   vertices {
#     x: 279
#     y: 826
#   }
#   vertices {
#     x: 279
#     y: 832
#   }
#   vertices {
#     x: 268
#     y: 832
#   }
# }
# , description: "311.90"
# bounding_poly {
#   vertices {
#     x: 293
#     y: 826
#   }
#   vertices {
#     x: 318
#     y: 826
#   }
#   vertices {
#     x: 318
#     y: 832
#   }
#   vertices {
#     x: 293
#     y: 832
#   }
# }
# , description: "Aras"
# bounding_poly {
#   vertices {
#     x: 72
#     y: 909
#   }
#   vertices {
#     x: 84
#     y: 909
#   }
#   vertices {
#     x: 84
#     y: 914
#   }
#   vertices {
#     x: 72
#     y: 914
#   }
# }
# , description: "17,"
# bounding_poly {
#   vertices {
#     x: 88
#     y: 909
#   }
#   vertices {
#     x: 95
#     y: 909
#   }
#   vertices {
#     x: 95
#     y: 914
#   }
#   vertices {
#     x: 88
#     y: 914
#   }
# }
# , description: "Wisma"
# bounding_poly {
#   vertices {
#     x: 98
#     y: 909
#   }
#   vertices {
#     x: 118
#     y: 909
#   }
#   vertices {
#     x: 118
#     y: 914
#   }
#   vertices {
#     x: 98
#     y: 914
#   }
# }
# , description: "TNB,"
# bounding_poly {
#   vertices {
#     x: 120
#     y: 909
#   }
#   vertices {
#     x: 134
#     y: 909
#   }
#   vertices {
#     x: 134
#     y: 914
#   }
#   vertices {
#     x: 120
#     y: 914
#   }
# }
# , description: "No."
# bounding_poly {
#   vertices {
#     x: 137
#     y: 909
#   }
#   vertices {
#     x: 146
#     y: 909
#   }
#   vertices {
#     x: 146
#     y: 914
#   }
#   vertices {
#     x: 137
#     y: 914
#   }
# }
# , description: "19."
# bounding_poly {
#   vertices {
#     x: 150
#     y: 909
#   }
#   vertices {
#     x: 157
#     y: 909
#   }
#   vertices {
#     x: 157
#     y: 914
#   }
#   vertices {
#     x: 150
#     y: 914
#   }
# }
# , description: "Jalan"
# bounding_poly {
#   vertices {
#     x: 160
#     y: 909
#   }
#   vertices {
#     x: 175
#     y: 909
#   }
#   vertices {
#     x: 175
#     y: 914
#   }
#   vertices {
#     x: 160
#     y: 914
#   }
# }
# , description: "Timur,"
# bounding_poly {
#   vertices {
#     x: 178
#     y: 909
#   }
#   vertices {
#     x: 195
#     y: 909
#   }
#   vertices {
#     x: 195
#     y: 914
#   }
#   vertices {
#     x: 178
#     y: 914
#   }
# }
# , description: "46200"
# bounding_poly {
#   vertices {
#     x: 198
#     y: 909
#   }
#   vertices {
#     x: 216
#     y: 909
#   }
#   vertices {
#     x: 216
#     y: 914
#   }
#   vertices {
#     x: 198
#     y: 914
#   }
# }
# , description: "Petaling"
# bounding_poly {
#   vertices {
#     x: 218
#     y: 909
#   }
#   vertices {
#     x: 241
#     y: 909
#   }
#   vertices {
#     x: 241
#     y: 915
#   }
#   vertices {
#     x: 218
#     y: 915
#   }
# }
# , description: "Jaya,"
# bounding_poly {
#   vertices {
#     x: 244
#     y: 909
#   }
#   vertices {
#     x: 259
#     y: 909
#   }
#   vertices {
#     x: 259
#     y: 915
#   }
#   vertices {
#     x: 244
#     y: 915
#   }
# }
# , description: "Selangor."
# bounding_poly {
#   vertices {
#     x: 262
#     y: 909
#   }
#   vertices {
#     x: 289
#     y: 909
#   }
#   vertices {
#     x: 289
#     y: 915
#   }
#   vertices {
#     x: 262
#     y: 915
#   }
# }
# , description: "TENAGA"
# bounding_poly {
#   vertices {
#     x: 72
#     y: 914
#   }
#   vertices {
#     x: 95
#     y: 914
#   }
#   vertices {
#     x: 95
#     y: 920
#   }
#   vertices {
#     x: 72
#     y: 920
#   }
# }
# , description: "NASIONAL"
# bounding_poly {
#   vertices {
#     x: 98
#     y: 914
#   }
#   vertices {
#     x: 128
#     y: 914
#   }
#   vertices {
#     x: 128
#     y: 921
#   }
#   vertices {
#     x: 98
#     y: 921
#   }
# }
# , description: "BERHAD"
# bounding_poly {
#   vertices {
#     x: 130
#     y: 914
#   }
#   vertices {
#     x: 152
#     y: 914
#   }
#   vertices {
#     x: 152
#     y: 921
#   }
#   vertices {
#     x: 130
#     y: 921
#   }
# }
# , description: "(200006),"
# bounding_poly {
#   vertices {
#     x: 155
#     y: 914
#   }
#   vertices {
#     x: 182
#     y: 914
#   }
#   vertices {
#     x: 182
#     y: 921
#   }
#   vertices {
#     x: 155
#     y: 921
#   }
# }
# , description: "Nombor"
# bounding_poly {
#   vertices {
#     x: 183
#     y: 914
#   }
#   vertices {
#     x: 203
#     y: 914
#   }
#   vertices {
#     x: 203
#     y: 920
#   }
#   vertices {
#     x: 183
#     y: 920
#   }
# }
# , description: "Datar"
# bounding_poly {
#   vertices {
#     x: 206
#     y: 914
#   }
#   vertices {
#     x: 221
#     y: 914
#   }
#   vertices {
#     x: 221
#     y: 920
#   }
#   vertices {
#     x: 206
#     y: 920
#   }
# }
# , description: "ST"
# bounding_poly {
#   vertices {
#     x: 224
#     y: 914
#   }
#   vertices {
#     x: 230
#     y: 914
#   }
#   vertices {
#     x: 230
#     y: 920
#   }
#   vertices {
#     x: 224
#     y: 920
#   }
# }
# , description: "W10-1608-31022372"
# bounding_poly {
#   vertices {
#     x: 233
#     y: 914
#   }
#   vertices {
#     x: 288
#     y: 914
#   }
#   vertices {
#     x: 288
#     y: 920
#   }
#   vertices {
#     x: 233
#     y: 920
#   }
# }
# ]

# %% [markdown]
# Convert the OCR output into text, and take only the first value.

# %%
tnb_raw = tnb_text[0].__str__()
tnb_raw
# Out:
# 'locale: "ms"\ndescription: "BIL ELEKTRIK ANDA\\nTENAGA\\nNASIONAL\\nNo. Akaun : 220001234512\\n: 1002000\\n: RM350.00\\nTERIMA KASIH\\nNo. Kontrak\\nKerana\\nDeposit\\nNo. Invois\\nMembayar Dalam\\nTempoh 30 Hari\\n: 10001234\\nAli bin Abu\\n3\\nTNB Careline\\n1-300-88-5454\\nE23A - 201 Sek 3\\nWangsa Maju\\n53300\\nWP Kuala Lumpur\\nTarikh Bil\\nJumlahPerlu Dibayar RM311.90\\n03 Okt 2018\\nAmaun\\nBayar Sebelum\\nTunggakan\\nCaj Semasa\\nPenggenapan\\nRM\\n0.00\\nTerima kasih\\nRM 311.88\\n0,02\\nRM\\nJumlah Bil\\nRM\\n311.90\\n01.11.2018\\nAmaun\\n52685\\nTarikh\\n5\\nBil Terdahulu\\nRM\\n02.08.2018\\nBayaran Akhir\\nRM\\n526.85\\n30.08.2018\\nJenis Bacaan\\nBacaan Sebenar\\nTempoh Bil : 03.09.2018 - 03.10.2018 (31 Hari)\\nTarif\\nFaktor Prorata\\n:A: Kediaman\\n1,00000\\nBlok Tarif (KWh)\\n200\\n100\\n300\\n300\\nBlok Prorata (kWh)\\n200\\n100\\n300\\n130\\nKadar (RM)\\n0.218\\nAmaun (RM)\\n43.60\\n33.40\\n154.80\\n70.98\\n8\\n0.334\\n0.516\\n0.546\\nJumlah\\n730\\n302.78\\nTidak Kena\\nST\\nKena\\nST\\nKeterangan\\nJumlah\\nKegunaan kWh\\nKegunaan\\nkWh\\n600\\n130\\n730\\nRM\\n231.80\\n70.98\\n302.78\\nKegunaan Bulan Semasa\\nService Tax (66)\\nKWTBB (1.6%)\\nRM\\n231.80\\n70.98\\n302.78\\n4.26\\n4.84\\n10\\nCaj Semasa\\nRM\\n311.88\\nBacaan Meter\\nNo Meter\\n\\320\\232egunaan\\nUnit\\nDahulu\\nSemasa\\n311201234\\n28470\\n29200\\n730\\nkWh\\nSubsidi 1.35 sen/kWh diblayai Kerajaan Persekutuan RM 10.61\\nService Tax (ST) 6% bagi penggunaan Domestik melebihi 600 kWh\\nBayaran melalui cek sah setelah penjelasan cek oleh bank\\n*22000123451200010001234000000000031190\\nAli bin Abu\\nE2SA - 201 Sek 3\\nWangsa Maju\\n53300\\nWP Kuala Lumpur\\nRM\\n311.90\\nAras 17, Wisma TNB, No. 19. Jalan Timur, 46200 Petaling Jaya, Selangor.\\nTENAGA NASIONAL BERHAD (200006), Nombor Datar ST W10-1608-31022372\\n"\nbounding_poly {\n  vertices {\n    x: 1\n    y: 14\n  }\n  vertices {\n    x: 325\n    y: 14\n  }\n  vertices {\n    x: 325\n    y: 921\n  }\n  vertices {\n    x: 1\n    y: 921\n  }\n}\n'

# %% [markdown]
# Seperate each value by the delimiter.

# %%
tnb_list = list(tnb_raw.split("\\n"))
tnb_list
# Out:
# ['locale: "ms"\ndescription: "BIL ELEKTRIK ANDA',
#  'TENAGA',
#  'NASIONAL',
#  'No. Akaun : 220001234512',
#  ': 1002000',
#  ': RM350.00',
#  'TERIMA KASIH',
#  'No. Kontrak',
#  'Kerana',
#  'Deposit',
#  'No. Invois',
#  'Membayar Dalam',
#  'Tempoh 30 Hari',
#  ': 10001234',
#  'Ali bin Abu',
#  '3',
#  'TNB Careline',
#  '1-300-88-5454',
#  'E23A - 201 Sek 3',
#  'Wangsa Maju',
#  '53300',
#  'WP Kuala Lumpur',
#  'Tarikh Bil',
#  'JumlahPerlu Dibayar RM311.90',
#  '03 Okt 2018',
#  'Amaun',
#  'Bayar Sebelum',
#  'Tunggakan',
#  'Caj Semasa',
#  'Penggenapan',
#  'RM',
#  '0.00',
#  'Terima kasih',
#  'RM 311.88',
#  '0,02',
#  'RM',
#  'Jumlah Bil',
#  'RM',
#  '311.90',
#  '01.11.2018',
#  'Amaun',
#  '52685',
#  'Tarikh',
#  '5',
#  'Bil Terdahulu',
#  'RM',
#  '02.08.2018',
#  'Bayaran Akhir',
#  'RM',
#  '526.85',
#  '30.08.2018',
#  'Jenis Bacaan',
#  'Bacaan Sebenar',
#  'Tempoh Bil : 03.09.2018 - 03.10.2018 (31 Hari)',
#  'Tarif',
#  'Faktor Prorata',
#  ':A: Kediaman',
#  '1,00000',
#  'Blok Tarif (KWh)',
#  '200',
#  '100',
#  '300',
#  '300',
#  'Blok Prorata (kWh)',
#  '200',
#  '100',
#  '300',
#  '130',
#  'Kadar (RM)',
#  '0.218',
#  'Amaun (RM)',
#  '43.60',
#  '33.40',
#  '154.80',
#  '70.98',
#  '8',
#  '0.334',
#  '0.516',
#  '0.546',
#  'Jumlah',
#  '730',
#  '302.78',
#  'Tidak Kena',
#  'ST',
#  'Kena',
#  'ST',
#  'Keterangan',
#  'Jumlah',
#  'Kegunaan kWh',
#  'Kegunaan',
#  'kWh',
#  '600',
#  '130',
#  '730',
#  'RM',
#  '231.80',
#  '70.98',
#  '302.78',
#  'Kegunaan Bulan Semasa',
#  'Service Tax (66)',
#  'KWTBB (1.6%)',
#  'RM',
#  '231.80',
#  '70.98',
#  '302.78',
#  '4.26',
#  '4.84',
#  '10',
#  'Caj Semasa',
#  'RM',
#  '311.88',
#  'Bacaan Meter',
#  'No Meter',
#  '\\320\\232egunaan',
#  'Unit',
#  'Dahulu',
#  'Semasa',
#  '311201234',
#  '28470',
#  '29200',
#  '730',
#  'kWh',
#  'Subsidi 1.35 sen/kWh diblayai Kerajaan Persekutuan RM 10.61',
#  'Service Tax (ST) 6% bagi penggunaan Domestik melebihi 600 kWh',
#  'Bayaran melalui cek sah setelah penjelasan cek oleh bank',
#  '*22000123451200010001234000000000031190',
#  'Ali bin Abu',
#  'E2SA - 201 Sek 3',
#  'Wangsa Maju',
#  '53300',
#  'WP Kuala Lumpur',
#  'RM',
#  '311.90',
#  'Aras 17, Wisma TNB, No. 19. Jalan Timur, 46200 Petaling Jaya, Selangor.',
#  'TENAGA NASIONAL BERHAD (200006), Nombor Datar ST W10-1608-31022372',
#  '"\nbounding_poly {\n  vertices {\n    x: 1\n    y: 14\n  }\n  vertices {\n    x: 325\n    y: 14\n  }\n  vertices {\n    x: 325\n    y: 921\n  }\n  vertices {\n    x: 1\n    y: 921\n  }\n}\n']

# %% [markdown]
# Identify the parts which contain the data I am looking for.

# %%
block = tnb_list[58:63]
block
# Out:
# ['Blok Tarif (KWh)', '200', '100', '300', '300']

# %%
prorated = tnb_list[63:68]
prorated
# Out:
# ['Blok Prorata (kWh)', '200', '100', '300', '130']

# %%
rate = tnb_list[68:70] + tnb_list[76:79]
rate
# Out:
# ['Kadar (RM)', '0.218', '0.334', '0.516', '0.546']

# %%
amount = tnb_list[70:75]
amount
# Out:
# ['Amaun (RM)', '43.60', '33.40', '154.80', '70.98']

# %% [markdown]
# Turn the lists into a table, and clean the table into an appropriate format.

# %%
import pandas as pd
compiled = pd.DataFrame([block, prorated, rate, amount]).T
compiled
# Out:
#                   0                   1           2           3
# 0  Blok Tarif (KWh)  Blok Prorata (kWh)  Kadar (RM)  Amaun (RM)
# 1               200                 200       0.218       43.60
# 2               100                 100       0.334       33.40
# 3               300                 300       0.516      154.80
# 4               300                 130       0.546       70.98

# %%
compiled.columns = compiled.iloc[0]

# %% [markdown]
# And here's the final result.

# %%
compiled = compiled.drop([0])
compiled
# Out:
# 0 Blok Tarif (KWh) Blok Prorata (kWh) Kadar (RM) Amaun (RM)
# 1              200                200      0.218      43.60
# 2              100                100      0.334      33.40
# 3              300                300      0.516     154.80
# 4              300                130      0.546      70.98
